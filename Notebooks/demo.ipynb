# %%
import os 
from dotenv import load_dotenv
import pandas as pd
import numpy as np
load_dotenv()
mongodb_username = os.environ.get('MONGODB_USER')
mongodb_password = os.environ.get('MONGODB_PASS')
mongodb_database="Vehicle-Insurance"

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = f"mongodb+srv://{mongodb_username}:{mongodb_password}@ml-clusters.qazmdxn.mongodb.net/{mongodb_database}?retryWrites=true&w=majority&appName=Ml-clusters"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# # load dataset

# %%
df = pd.read_csv('data.csv')

# %%
dictionary = df.to_dict(orient='records')

# %%
database = client[mongodb_database]
collection = database['vehicle_insurance']

# %%
if dictionary:
    results = collection.insert_many(dictionary)
    print(f"✅ Inserted {len(results)} records into MongoDB")
else:
    print("⚠️ No data found in CSV")
